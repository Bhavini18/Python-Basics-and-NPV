# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="10%">
#             <img src="homework.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b>Take - home
#                         <br> (Day 3)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### Let's begin with some hands-on practice exercises.
#
# **Create a dataframe wherever necessary**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 1. Compute minimum and maximum sales for each store and location
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
sn= ['A', 'B', 'A', 'C', 'D', 'A', 'D', 'A', 'C', 'B']
cn= ['Mumbai', 'Pune', 'Hyderabad', 'Mumbai', 'Pune', 'Delhi', 'Hyderabad', 'Pune', 'Mumbai', 'Pune']
sale= [40000, 45000, 50000, 90000, 89000, 87000, 85000, 78000,89000, 70000]
colm= ['Store', 'Location', 'Sales']
df= pd.DataFrame(list(zip(sn,cn,sale)), columns= colm)
df
# Out:
#   Store   Location  Sales
# 0     A     Mumbai  40000
# 1     B       Pune  45000
# 2     A  Hyderabad  50000
# 3     C     Mumbai  90000
# 4     D       Pune  89000
# 5     A      Delhi  87000
# 6     D  Hyderabad  85000
# 7     A       Pune  78000
# 8     C     Mumbai  89000
# 9     B       Pune  70000

# %%
Min_Max= df.pivot_table(values= 'Sales', index= 'Store', columns= 'Location', aggfunc=[np.min, np.max])
Min_Max
# Out:
#              amin                                 amax                     \
# Location    Delhi Hyderabad   Mumbai     Pune    Delhi Hyderabad   Mumbai
# Store
# A         87000.0   50000.0  40000.0  78000.0  87000.0   50000.0  40000.0
# B             NaN       NaN      NaN  45000.0      NaN       NaN      NaN
# C             NaN       NaN  89000.0      NaN      NaN       NaN  90000.0
# D             NaN   85000.0      NaN  89000.0      NaN   85000.0      NaN
#
#
# Location     Pune
# Store
# A         78000.0
# B         70000.0
# C             NaN
# D         89000.0

# %%
#Using Group-by

df['Sales'].groupby([df['Store'], df['Location']]).max()

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 2. Find duplicate rows based on the column 'Name'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Salary</th>
# <th>City</th>
# </tr>
# <tr>
# <td>John</td>
# <td>3400</td>
# <td>Sydeny</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>1600</td>
# <td>New York</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Texas</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>4000</td>
# <td>London</td>
# </tr>
# <tr>
# <td>Sachin</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
#
# </table>

# %%
n= ['John', 'Robert', 'Aadi', 'Robert', 'Robert', 'Robert', 'Aadi', 'Sachin']
s= [3400, 3000, 1600, 3000, 3000, 3000, 4000, 3000]
c= ['Sydeny', 'Chicago' ,'New York', 'Chicago' ,'Chicago' ,' Texas','London','Chicago']
colmn= ['Name', 'Salary', 'City']
df2= pd.DataFrame(list(zip(n,s,c)), columns= colmn)
df2
# Out:
#      Name  Salary      City
# 0    John    3400    Sydeny
# 1  Robert    3000   Chicago
# 2    Aadi    1600  New York
# 3  Robert    3000   Chicago
# 4  Robert    3000   Chicago
# 5  Robert    3000     Texas
# 6    Aadi    4000    London
# 7  Sachin    3000   Chicago

# %%
df2[df2['Name'].duplicated(keep='first')]
# Out:
#      Name  Salary     City
# 3  Robert    3000  Chicago
# 4  Robert    3000  Chicago
# 5  Robert    3000    Texas
# 6    Aadi    4000   London

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 3.  In column tournament, replace all the 'football' values  with 'cricket' using numpy.where
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#
# <table>
# <tr>
# <th>Days</th>
# <th>Tournament</th>
# </tr>
# <tr>
# <td>Mon</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Tues</td>
# <td>Cricket</td>
# </tr>
# <tr>
# <td>Wed</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Thurs</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Fri</td>
# <td>Cricket</td>
# </tr>
#
# </table>

# %%
day= ['Mon', 'Tues', 'Wed', 'Thurs', 'Fri']
tour= ['Football', 'Cricket', 'Football', 'Football', 'Cricket']
df3= pd.DataFrame(list(zip(day,tour)), columns=['Days', 'Tournament'])
df3
# Out:
#     Days Tournament
# 0    Mon   Football
# 1   Tues    Cricket
# 2    Wed   Football
# 3  Thurs   Football
# 4    Fri    Cricket

# %%
df3['Tournament'] = np.where(df3['Tournament'] == 'Football', 'Cricket', 'Cricket')
df3
# Out:
#     Days Tournament
# 0    Mon    Cricket
# 1   Tues    Cricket
# 2    Wed    Cricket
# 3  Thurs    Cricket
# 4    Fri    Cricket

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 4. Get the descriptive statistics of the sales for each season
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Month</th>
# <th>Sales</th>
# <th>Seasons</th>
# </tr>
# <tr>
# <td>Jan</td>
# <td>22000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Feb</td>
# <td>27000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Mar</td>
# <td>25000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>Apr</td>
# <td>29000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>May</td>
# <td>35000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>June</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>July</td>
# <td>78000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Aug</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Sep</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Oct</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Nov</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Dec</td>
# <td>60000</td>
# <td>Winter</td>
# </tr>
#
# </table>

# %%
Mon= ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'June', 'July', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
s= [22000, 27000, 25000, 29000, 35000, 67000, 78000, 67000, 56000, 56000, 56000, 60000]
sea= ['Winter', 'Winter', 'Spring', 'Spring', 'Spring', 'Summer', 'Summer', 'Summer', 'Fall', 'Fall', 'Fall', 'Winter']
df4= pd.DataFrame(list(zip(Mon,s,sea)), columns= ['Month', 'Sales', 'Seasons'])
df4
# Out:
#    Month  Sales Seasons
# 0    Jan  22000  Winter
# 1    Feb  27000  Winter
# 2    Mar  25000  Spring
# 3    Apr  29000  Spring
# 4    May  35000  Spring
# 5   June  67000  Summer
# 6   July  78000  Summer
# 7    Aug  67000  Summer
# 8    Sep  56000    Fall
# 9    Oct  56000    Fall
# 10   Nov  56000    Fall
# 11   Dec  60000  Winter

# %%
df4['Sales'].groupby(df4['Seasons']).describe()
# Out:
#          count          mean           std      min      25%      50%  \
# Seasons
# Fall       3.0  56000.000000      0.000000  56000.0  56000.0  56000.0
# Spring     3.0  29666.666667   5033.222957  25000.0  27000.0  29000.0
# Summer     3.0  70666.666667   6350.852961  67000.0  67000.0  67000.0
# Winter     3.0  36333.333333  20647.840888  22000.0  24500.0  27000.0
#
#              75%      max
# Seasons
# Fall     56000.0  56000.0
# Spring   32000.0  35000.0
# Summer   72500.0  78000.0
# Winter   43500.0  60000.0

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 5. Create a new column age with values of your choice. And append it to the below dataframe.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Maths</th>
# <th>Science</th>
# <th>English</th>
# </tr>
# <tr>
# <td>Emma</td>
# <td>56</td>
# <td>89</td>
# <td>89</td>
# </tr>
# <tr>
# <td>Mia</td>
# <td>78</td>
# <td>87</td>
# <td>89</td>
# </tr>
# <tr>
# <td>Sophia</td>
# <td>78</td>
# <td>78</td>
# <td>76</td>
# </tr>
# <tr>
# <td>James</td>
# <td>67</td>
# <td>89</td>
# <td>78</td>
# </tr>
# <td>John</td>
# <td>88</td>
# <td>78</td>
# <td>87</td>
# </tr>
#
# </table>

# %%
na= ['Emma', 'Mia', 'Sophia', 'James', 'John']
math= [56, 78, 78, 67, 88]
sc= [89, 87, 78, 89, 78]
eng= [89, 89, 76, 78, 87]
col5= ['Name','Maths', 'Science', 'English']
df5= pd.DataFrame(list(zip(na, math, sc, eng)), columns= col5)
df5
# Out:
#      Name  Maths  Science  English
# 0    Emma     56       89       89
# 1     Mia     78       87       89
# 2  Sophia     78       78       76
# 3   James     67       89       78
# 4    John     88       78       87

# %%
a= pd.Series((11,32,34,43,51), name= 'Age')
pd.concat((df5,a), axis=1)
# Out:
#      Name  Maths  Science  English  Age
# 0    Emma     56       89       89   11
# 1     Mia     78       87       89   32
# 2  Sophia     78       78       76   34
# 3   James     67       89       78   43
# 4    John     88       78       87   51

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 6. Perform right join to combine values based on the columns 'MA(Hons)' and 'Stud_ID' in the two dataframes
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
#     <tr>
#         <th>Stud_ID</th>
#         <th>Name</th>
#         <th>MA(Hons)</th>
#     </tr>
#     <tr>
#         <td>101</td>
#         <td>Alex</td>
#         <td>History</td>
#     </tr>
#     <tr>
#         <td>102</td>
#         <td>Amy</td>
#         <td>English</td>
#     </tr>
#     <tr>
#         <td>103</td>
#         <td>Allen</td>
#         <td>Geography</td>
#     </tr>
#     <tr>
#         <td>104</td>
#         <td>Alice</td>
#         <td>German</td>
#     </tr>
#         <td>105</td>
#         <td>James</td>
#         <td>History</td>
#     </tr>
# </table>
# <br>
#
#
#
# <table>
#     <tr>
#         <th>Stud_ID</th>
#         <th>Res_City</th>
#         <th>MA(Hons)</th>
#     </tr>
#     <tr>
#         <td>101</td>
#         <td>Delhi</td>
#         <td>English</td>
#     </tr>
#     <tr>
#         <td>102</td>
#         <td>Mumbai</td>
#         <td>History</td>
#     </tr>
#     <tr>
#         <td>103</td>
#         <td>Delhi</td>
#         <td>Fine Arts</td>
#     </tr>
#     <tr>
#         <td>104</td>
#         <td>Chennai</td>
#         <td>German</td>
#     </tr>
#         <td>105</td>
#         <td>Hyderabad</td>
#         <td>History</td>
#     </tr>
# </table>

# %%
st_id1= [101, 102, 103, 104, 105]
name1= ['Alex', 'Amy', 'Allen', 'Alice', 'James']
ma1= [ 'History', 'English', 'Geography', 'German', 'History']
df6= pd.DataFrame(list(zip(st_id1, name1, ma1)), columns= ['Stud_ID', 'Name', 'MA(Hons)'])
df6
# Out:
#    Stud_ID   Name   MA(Hons)
# 0      101   Alex    History
# 1      102    Amy    English
# 2      103  Allen  Geography
# 3      104  Alice     German
# 4      105  James    History

# %%
st_id2= [101, 102, 103, 104, 105]
res_city= ['Delhi', 'Mumbai', 'Delhi', 'Chennai', 'Hyderabad']
ma2= ['English', 'History', 'Fine Arts', 'German', 'History']
df7= pd.DataFrame(list(zip(st_id2, res_city, ma2)), columns= ['Stud_ID', 'Res_city', 'MA(Hons)'])
df7
# Out:
#    Stud_ID   Res_city   MA(Hons)
# 0      101      Delhi    English
# 1      102     Mumbai    History
# 2      103      Delhi  Fine Arts
# 3      104    Chennai     German
# 4      105  Hyderabad    History

# %%
df6.set_index(['Stud_ID', 'MA(Hons)'], inplace= True)
df7.set_index(['Stud_ID','MA(Hons)'], inplace= True)

# %%
df6.join(df7, how='right', rsuffix='df7')
# Out:
#                     Name   Res_city
# Stud_ID MA(Hons)
# 101     English      NaN      Delhi
# 102     History      NaN     Mumbai
# 103     Fine Arts    NaN      Delhi
# 104     German     Alice    Chennai
# 105     History    James  Hyderabad

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 7. Using the dataframes created in question 6, perform inner join to combine values based on the columns 'MA(Hons)' and 'Stud_ID' in the two dataframes
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df6.set_index('MA(Hons)', inplace=True)
df7.set_index('MA(Hons)', inplace=True)

# %%
df6.join(df7, how= 'inner', lsuffix='new')
# Out:
#           Stud_IDnew   Name  Stud_ID   Res_city
# MA(Hons)
# English          102    Amy      101      Delhi
# German           104  Alice      104    Chennai
# History          101   Alex      102     Mumbai
# History          101   Alex      105  Hyderabad
# History          105  James      102     Mumbai
# History          105  James      105  Hyderabad

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 8. Concatenate two dataframes along the columns
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
#     <tr>
#         <th>Stud_ID</th>
#         <th>Name</th>
#     </tr>
#     <tr>
#         <td>101</td>
#         <td>Alex</td>
#     </tr>
#     <tr>
#         <td>102</td>
#         <td>Amy</td>
#     </tr>
#     <tr>
#         <td>103</td>
#         <td>Allen</td>
#     <tr>
#         <td>104</td>
#         <td>Alice</td>
#     </tr>
#         <td>105</td>
#         <td>James</td>
#     </tr>
# </table>
# <br>
#
#
#
# <table>
#     <tr>
#         <th>Res_City</th>
#         <th>MA(Hons)</th>
#     </tr>
#     <tr>
#         <td>Delhi</td>
#         <td>English</td>
#     </tr>
#     <tr>
#         <td>Mumbai</td>
#         <td>History</td>
#     </tr>
#     <tr>
#         <td>Delhi</td>
#         <td>Fine Arts</td>
#     </tr>
#     <tr>
#         <td>Chennai</td>
#         <td>German</td>
#     </tr>
#         <td>Hyderabad</td>
#         <td>History</td>
#     </tr>
# </table>

# %%
d3= df6[['Stud_ID', 'Name']]
d4= df7[['Res_city', 'MA(Hons)']]

# %%
pd.concat([d3,d4], axis=1)
# Out:
#    Stud_ID   Name   Res_city   MA(Hons)
# 0      101   Alex      Delhi    English
# 1      102    Amy     Mumbai    History
# 2      103  Allen      Delhi  Fine Arts
# 3      104  Alice    Chennai     German
# 4      105  James  Hyderabad    History

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 9. Calculate minimum, maximum and average sales for each season
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Alex</td>
# <td>Maths</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Amy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Allen</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Alice</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Ayoung</td>
# <td>History</td>
# </tr>
#
# </table><br>
#
#
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Billy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Brian</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Bran</td>
# <td>Social Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Bryce</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Betty</td>
# <td>History</td>
# </tr>
#
# </table>

# %%
df4
# Out:
#    Month  Sales Seasons
# 0    Jan  22000  Winter
# 1    Feb  27000  Winter
# 2    Mar  25000  Spring
# 3    Apr  29000  Spring
# 4    May  35000  Spring
# 5   June  67000  Summer
# 6   July  78000  Summer
# 7    Aug  67000  Summer
# 8    Sep  56000    Fall
# 9    Oct  56000    Fall
# 10   Nov  56000    Fall
# 11   Dec  60000  Winter

# %%
new= df4['Sales'].groupby(df4['Seasons'])
print(new.min())
print(new.max())
print(new.mean())
# Out:
# Seasons
# Fall      56000
# Spring    25000
# Summer    67000
# Winter    22000
# Name: Sales, dtype: int64
# Seasons
# Fall      56000
# Spring    35000
# Summer    78000
# Winter    60000
# Name: Sales, dtype: int64
# Seasons
# Fall      56000.000000
# Spring    29666.666667
# Summer    70666.666667
# Winter    36333.333333
# Name: Sales, dtype: float64

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 10. Find all the duplicate entries based on the columns X and Y.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>X</th>
# <th>Y</th>
# <th>Z</th>
# </tr>
# <tr>
# <td>1</td>
# <td>2</td>
# <td>5</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>6</td>
# </tr>
# <tr>
# <td>3</td>
# <td>1</td>
# <td>2</td>
# </tr>
# <tr>
# <td>1</td>
# <td>2</td>
# <td>6</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>1</td>
# </tr>
# <tr>
# <td>3</td>
# <td>4</td>
# <td>6</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>2</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>8</td>
# </tr>
#
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Month</th>
# <th>Sales</th>
# <th>Seasons</th>
# </tr>
# <tr>
# <td>Jan</td>
# <td>22000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Feb</td>
# <td>27000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Mar</td>
# <td>25000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>Apr</td>
# <td>29000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>May</td>
# <td>35000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>June</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>July</td>
# <td>78000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Aug</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Sep</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Oct</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Nov</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Dec</td>
# <td>60000</td>
# <td>Winter</td>
# </tr>
#
# </table>

# %%
x= [1,2,3,1,2,3,2,2]
y= [2,2,1,2,2,4,2,2]
z= [5,6,2,6,1,6,2,8]
col= pd.DataFrame(list(zip(x,y,z)), columns= ['X', 'Y', 'Z'])
col
# Out:
#    X  Y  Z
# 0  1  2  5
# 1  2  2  6
# 2  3  1  2
# 3  1  2  6
# 4  2  2  1
# 5  3  4  6
# 6  2  2  2
# 7  2  2  8

# %%
col.set_index('Z', inplace= True)

# %%
col[col.duplicated()]
# Out:
#    X  Y
# Z
# 6  1  2
# 1  2  2
# 2  2  2
# 8  2  2
